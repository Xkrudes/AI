# %%
"""Задание 1.1.4 Р/т №5"""

import math

class TrigonometryFunctions:
    @staticmethod
    def cosine(angle):
        return math.cos(angle)

    @staticmethod
    def sine(angle):
        return math.sin(angle)

    @staticmethod
    def tangent(angle):
        return math.tan(angle)

    @staticmethod
    def arcsine(value):
        return math.asin(value)

    @staticmethod
    def arccosine(value):
        return math.acos(value)

    @staticmethod
    def arctangent(value):
        return math.atan(value)

    @staticmethod
    def degrees_to_radians(degrees):
        return math.radians(degrees)

trig_functions = TrigonometryFunctions()
value_in_degrees = 45
value = trig_functions.degrees_to_radians(value_in_degrees)

cosine_value = trig_functions.cosine(value)
print(f"Cosine({value_in_degrees} degrees) = {cosine_value}")
# Out:
# Cosine(45 degrees) = 0.7071067811865476

# %%
"""Задание 1.2.3 Р/т №5"""

Tree = ['a',
        ['b',
          ['d', None, None],
          ['e', None, None]
        ],
        ['c',
          ['f', None, None]
        ]
       ]

print(f'Корень = {Tree[0]}, его левое и правое поддеревья = {Tree[1], Tree[2]}')
# Out:
# Корень = a, его левое и правое поддеревья = (['b', ['d', None, None], ['e', None, None]], ['c', ['f', None, None]])

# %%
"""Задание 1.2.4 Р/т №5"""


class Tree:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data
    
    def Insert(self, new_data):
        if new_data < self.data:
            if self.left is None:
                self.left = Tree(new_data)
            else:
                self.left.Insert(new_data)
        elif new_data > self.data:
            if self.right is None:
                self.right = Tree(new_data)
            else:
                self.right.Insert(new_data)

    def PrintTree(self, count):
        if self.left:
            self.left.PrintTree(count)
        print(self.data)
        if self.right:
            self.right.PrintTree(count)


tree = Tree(5)
tree.Insert(3)
tree.Insert(7)
tree.Insert(1)
tree.Insert(4)

tree.PrintTree(0)
# Out:
# 1
# 3
# 4
# 5
# 7

# %%
"""Задание 1.3.2 Р/т №5"""
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree


X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
target = [0, 0, 0, 1, 1, 1]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    target,
    test_size=0.20
)

classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
tree.plot_tree(classifier)

y_pred = classifier.predict(X_test)
print(y_test, y_pred)
# Out:
# [0, 0] [0 0]

# %%
"""Задание 1.4.2 Р/т №5"""
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn import metrics


url = 'https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv'
dataset = pd.read_csv(url)



x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

X_train, X_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=0
)

regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
tree.plot_tree(regressor)

y_pred = regressor.predict(X_test)

print(f'Mean Squared Error: {metrics.mean_squared_error(y_test, y_pred)}')
print(f'Mean Absolute Error: {metrics.mean_absolute_error(y_test, y_pred)}')

df = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df
# Out:
# Mean Squared Error: 17180.1
# Mean Absolute Error: 100.3
#    Actual  Predicted
# 0    3601     3635.0
# 1    4399     4447.0
# 2    3448     3357.0
# 3    3640     3635.0
# 4    3063     3357.0
# 5    3897     3802.0
# 6    3528     3635.0
# 7    4449     4512.0
# 8    5126     5342.0
# 9    4391     4341.0
