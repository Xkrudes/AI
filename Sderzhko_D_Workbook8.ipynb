# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
"""Задание 1.1.2 Р/т №8"""

X = np.array([[5,3],
[10,15],
[15,12],
[24, 10],
[30,45],
[85,70],
[71,80],
[60,78],
[55,52],
[80,91]])
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)
y_kmeans=kmeans.predict(X)
centers = kmeans.cluster_centers_
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=20, cmap='summer')
plt.scatter(centers[:, 0], centers[:,1], c='blue', s=100, alpha = 0.9)
plt.show()
# Out:
# c:\Users\Денис\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
"""Задание 1.1.3 Р/т №8"""

iris = sns.load_dataset('iris')
X_train, X_test, y_train, y_test=train_test_split(
    iris.iloc[:,:-1],
    iris.iloc[:,-1],
    test_size=0.20
)
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)
plt.figure(figsize=(10,7))
sns.scatterplot(x='petal_width', y='petal_length', data=iris, hue='species', s=70)
plt.xlabel("Длинна лепестка, см")
plt.ylabel("Ширина лепестка, см")
plt.legend(loc=2)
# Out:
# c:\Users\Денис\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
"""Задание 1.2.3 Р/т №8"""
from sklearn.cluster import AgglomerativeClustering

data = iris.iloc[:, 2:4].values
cluster = AgglomerativeClustering(n_clusters=3)
cluster.fit_predict(data)
plt.scatter(data[:,1], data[:,0], c = cluster.labels_, cmap='rainbow')
